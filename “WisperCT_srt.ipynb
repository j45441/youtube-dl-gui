# %% [markdown]
# <a href="https://colab.research.google.com/github/j45441/youtube-dl-gui/blob/master/%E2%80%9CWisperCT_srt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/Softcatala/whisper-ctranslate2
# Out:
# ...
#   Cloning https://github.com/Softcatala/whisper-ctranslate2 to /tmp/pip-req-build-jr0bm5zs
#   Running command git clone --filter=blob:none --quiet https://github.com/Softcatala/whisper-ctranslate2 /tmp/pip-req-build-jr0bm5zs
#   Resolved https://github.com/Softcatala/whisper-ctranslate2 to commit 47a950a095a65d6cdf1a2412cf2fddbb1860370c
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 60.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 119.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.3 MB/s eta 0:00:00
# ...

# %%
# !pip install -U whisper-ctranslate2

# %%
#翻译成中文
# !whisper-ctranslate2 1028.MP3 --device cuda --model large-v3
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 2.87MB/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# vocabulary.json: 0.00B [00:00, ?B/s]
#
# config.json: 2.39kB [00:00, 9.16MB/s]
# vocabulary.json: 1.07MB [00:00, 41.2MB/s]
# tokenizer.json: 2.48MB [00:00, 75.2MB/s]
# model.bin: 100% 3.09G/3.09G [01:15<00:00, 40.7MB/s]
# Detected language 'Chinese' with probability 0.997070
# [00:00.180 --> 00:03.200] 你还在因为没有剪映会员而苦恼吗?
# [00:03.380 --> 00:07.020] 配音要收费,素材要收费,字幕模板还有限制
# [00:07.020 --> 00:09.980] 最离谱的是导出高清还有开通VIP
# [00:09.980 --> 00:11.920] 剪映越运越憋屈,是不是?
# [00:12.720 --> 00:15.540] 其实真正聪明的人早就不用剪映了
# [00:15.540 --> 00:18.560] 今天告诉你一个全新玩法
# [00:18.560 --> 00:21.260] 比剪映猛十倍的神器组合
# [00:21.260 --> 00:23.160] 零显卡零配置
# [00:23.160 --> 00:27.060] 用谷歌Callable一键运行Index TTS2和Whisper
# [00:27.360 --> 00:29.560] 没听错,不需要安装软件
# [00:29.560 --> 00:33.640] 不用代码,也不需要懂代码
# ...

# %%
#翻译成英文
# !whisper-ctranslate2 1028.MP3 --device cuda --model large-v3 --task translate
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json: 2.39kB [00:00, 2.85MB/s]
#
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 450kB/s]
#
# tokenizer.json: 2.48MB [00:00, 79.0MB/s]
# vocabulary.json: 1.07MB [00:00, 72.1MB/s]
# model.bin: 100% 3.09G/3.09G [00:57<00:00, 53.8MB/s]
# Detected language 'Chinese' with probability 0.999023
# [00:00.000 --> 00:10.000]  This program introduces how to register a free US Apple ID and a Hong Kong-Taiwan Apple ID.
# [00:10.000 --> 00:19.000]  First of all, you need an email address that you have not registered with this Apple ID.
# [00:19.000 --> 00:23.000]  And a phone number that you have not registered with this Apple ID.
# [00:23.000 --> 00:25.000]  A phone number of 886 is fine.
# [00:25.000 --> 00:34.000]  This tutorial is not only to register a US Apple ID.
# ...

# %%
 # !curl ipinfo.io
# Out:
# {
#   "ip": "34.83.121.119",
#   "hostname": "119.121.83.34.bc.googleusercontent.com",
#   "city": "The Dalles",
#   "region": "Oregon",
#   "country": "US",
#   "loc": "45.5946,-121.1787",
#   "org": "AS396982 Google LLC",
#   "postal": "97058",
#   "timezone": "America/Los_Angeles",
#   "readme": "https://ipinfo.io/missingauth"
# }
